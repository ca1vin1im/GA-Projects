# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# - Analyse trends in both the ACT and SAT participation rates to identify potential strategies for improving 2020 ACT participation rates and eventually reclaim its position as the nation’s most widely used college admission test. The rival College Board's SAT is more widely taken by graduating seniors since 2018 ([*source*](https://www.washingtonpost.com/education/2018/10/23/sat-reclaims-title-most-widely-used-college-admission-test/)). In the class of 2019, over 2.2 million students ([*source*](https://www.prnewswire.com/news-releases/over-2-2-million-students-in-class-of-2019-took-sat-largest-group-ever-300923736.html)) took the SAT as compared to over 1.78 million graduates ([*source*](https://www.act.org/content/dam/act/unsecured/documents/National-CCCR-2019.pdf)) who took the ACT.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# **Additional Information:**
#
# **ACT**
# - ACT Score Components: The required portion of the ACT is divided into 4 multiple choice subject tests: English, mathematics, reading, and science reasoning. [(source)](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)
#  - Composite score: 1 to 36 (Average of the number of correct answers converts to a score ranging from 1 to 36 for each of the 4 tests)
#  - Subscore (English, Math, Reading, Science): 1 to 36 (All in 1-point increments.)
#  - Optional Writing Score: 2 to 12. (Sum of two graders’ scoring from 1-6)
# - Students cannot cancel their ACT scores. However, they may retake the ACT test multiple times, and their scores from each test date are reported separately. Therefore, students can elect to send only the scores from their most successful test date(s) to colleges. [(source)](https://www.princetonreview.com/college/act-faqs)
# - Students testing on a national test date, who cannot afford the registration fee for the ACT or ACT with writing, may be eligible for an ACT Fee Waiver. Information about the eligibility requirements and how to request a fee waiver is sent each summer to high schools. [(source)](https://success.act.org/s/topic/0TO1B000000UBWwWAO/the-act-faq)
#
# **SAT**
# - SAT Score Components: The SAT is scored out of 1600 and is a combination of the section scores (800 for reading/writing and math respectively). The essay is optional and will not be factored into the overall SAT score. The essay scores will be shown separately on the report [(source)](https://www.khanacademy.org/test-prep/sat/new-sat-tips-planning/new-sat-about-sat/a/scoring-on-the-redesigned-sat).
# - SAT is not compulsory for all States and requires a registration fee, hence some States may have lower participation rates [(source)](https://collegereadiness.collegeboard.org/sat/register/fees).
# - College do not rely only on SAT to judge applicants, they also rely on GPA/transcript [(source)](https://blog.prepscholar.com/what-do-colleges-look-for).
# - Students can take the SAT multiple times, and most colleges consider a student's highest SAT score when making admission decisions. And if they get a total SAT score by at least 100 points higher than their previous SAT score, they could be eligible to earn an Improve Your Score scholarship worth 2,000 dollars [(source)](https://parents.collegeboard.org/faq/how-many-times-can-student-take-sat-when-should-take).
# - Many schools use a process called "superscoring", which combines a student's highest Math section score with their highest Evidence-Based Reading and Writing section score, even if those scores are from different test dates, to come up with the student's total SAT score [(source)](https://parents.collegeboard.org/faq/how-many-times-can-student-take-sat-when-should-take).
# <br>

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **Datasets selected:**
# - act_2017.csv: 2017 ACT Scores by State
# - act_2018.csv: 2018 ACT Scores by State
# - act_2019.csv: 2019 ACT Scores by State
# - sat_2017.csv: 2017 SAT Scores by State
# - sat_2018.csv: 2018 SAT Scores by State
# - sat_2019.csv: 2019 SAT Scores by State
# <br>
#
# **Brief Description of Datasets selected:**
# - The 6 datasets above provides data on the participation rate of high school students in each state who took the ACT and/or SAT in 2017, 2018 and 2019, and with their average scores aggregated at state-level. They will be used to identify states where ACT/SAT participation rates have increased/decreased significantly over the years.

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **Additional Information:**
#
# - The SAT is geared toward testing logic, while the ACT is considered more a test of accumulated knowledge. [(source)](http://content.time.com/time/nation/article/0,8599,1947019,00.html)
# - According to independent researchers who published the paper "SAT and ACT Scores as Predictors of Undergraduate GPA Scores of Construction Science and Management Students", the authors concluded that both SAT and ACT were valid and reliable predictors of Undergraduate Grade Point Average (UGPA) in undergraduate CSM programs. The correlation and regression coefficients between UGPA and ACT/SAT were relatively strong implying relatively good predictive ability of undergraduate educational performance and success. In some of the statistical analyses, ACT showed better predictive power than SAT for the UGPAs of students and so the undergraduate Construction Science and Management (CSM) programs and admission committees may reconsider re-assessing their admission requirements. [(source)](https://www.researchgate.net/profile/Joel-Wao/publication/316554186_SAT_and_ACT_Scores_as_Predictors_of_Undergraduate_GPA_Scores_of_Construction_Science_and_Management_Students/links/590399ab0f7e9bc0d58d7e30/SAT-and-ACT-Scores-as-Predictors-of-Undergraduate-GPA-Scores-of-Construction-Science-and-Management-Students.pdf)
# - ACT introduces 3 new options for students taking its test used in college admissions effective Sep2020 [(source)](https://www.forbes.com/sites/michaeltnietzel/2019/10/08/act-has-just-unveiled-new-testing-options/?sh=27d817ed33c7):
#  - **ACT Section Retesting**: For the first time in the ACT’s history, students who have taken the test once will be given the option of retaking any one of the individual section tests (English, math, reading, science, and/or writing) rather than having to take the entire test again. Historically, about half of ACT test-takers repeat the test in an attempt to better their scores.
#  - **Online testing with faster score turnaround**: Also for the first time, students will be able to take the test online during national test days at ACT test centers. The test is currently administered only in a paper-and-pencil format on national test days. Students who elect to take the online test will learn their results in two days as opposed to the typical two-week time lag for the paper-pencil administration.
#  - **New ACT “superscoring”**: For students who have taken the test more than once or who retake individual sections of it, ACT will permit them to combine their best scores on the subtests across all administrations, rather than the scores from just one sitting. This “pick and choose” option will, of course, allow students to report a higher combined score than the more restrictive, former method.
# - Naviance by Hobsons’ Director of Thought Leadership, Dr. Kim Oppelt believes the changes are positive for several reasons. “Superscoring will help to even the playing field for students who apply to multiple institutions” by automatically highlighting their best scores. She added, “ACT section retesting will be an asset to those with learning differentiations,” and “(it) will benefit students from low-income backgrounds” because they will be better able to afford paying for just one section instead of having to pay for the complete assessment. [(source)](https://www.forbes.com/sites/michaeltnietzel/2019/10/08/act-has-just-unveiled-new-testing-options/?sh=27d817ed33c7)
# <br>
#
# - The College Board's new president and CEO, David Coleman, had served as one of the lead writers of the Common Core Standards, the then-new K-12 education standards that 45 states initially adopted. He formulated a strategy to position SAT as the high school accountability test that 11 graders are required to take, no matter what these 11 graders planned to do after graduating. [(source)](https://www.newamerica.org/education-policy/edcentral/how-college-boards-aggressive-campaign-to-save-the-sat-may-kill-it/)
#  - Under Coleman, the College Board aggressively doubled expenditures to lobby states to require their 11th graders to take the SAT. For example, from July 2015 through June 2016, the College Board spent \$67,492 on state level lobbying in Colorado, which flipped from the ACT to the SAT in the 2015-16 academic year.
#  - Among other things, the organization lobbied to defeat a bill in the state legislature that would have given Colorado school districts more flexibility to choose which 10th and 11th grade accountability tests they wanted to administer. Had the bill passed, the districts could have chosen to require students take the ACT over the SAT.
#  - The College Board also recruited Paul Weeks, the architect of ACT’s state testing strategy, away from ACT.
# - States that require the ACT: Alabama, Hawaii, Idaho, Kentucky, Louisiana, Mississippi, Missouri, Montana, Nebraska, Nevada, North Carolina, North Dakota, Ohio, South Carolina, Tennessee, Utah, Wisconsin, Wyoming [(source)](https://testive.com/state-sat-act/)
# - States that require the SAT: Colorado, Connecticut, Delaware, District of Columbia, Idaho, Illinois, Maine, Michigan, New Hampshire, Ohio, Tennessee [(source)](https://testive.com/state-sat-act/)
# - Alaska's high school students no longer required by state law to take the SAT, ACT or WorkKeys test to get their diplomas as the law expired 30Jun2016. [(source)](https://www.adn.com/alaska-news/education/2016/06/30/students-no-longer-need-national-tests-to-graduate/)
# - Arizona allows for its 55 public schools to measure high school students’ proficiency in Arizona academic standards with the ACT or SAT effective 2019 instead of AzMERIT. 44 of these 55 schools chose ACT over SAT, citing reasons of lesser time needed to take the ACT (vs AzMERIT), greater student ownership, value and meaning. This probably led to the rise in ACT participation rate by 7% from 2018 in 2019. [(source)](https://azednews.com/why-some-schools-chose-the-act-or-sat-over-azmerit/)
# - Colorado state mandated SAT for all high school juniors effective 11Apr2017. [(source)](https://testive.com/colorado-sat-change-2017/)
# - More Florida students took the SAT in 2018 than ever before, pushed by free test sessions at their schools. [(source)](https://www.orlandosentinel.com/news/education/os-ne-act-sat-florida-scores-20181024-story.html)
# - In Florida, more students are taking the SAT exam largely because of “SAT school day” programs that allow for taking the exam during the week, at their school, free of charge. Many Florida school districts now offer such programs, driving up SAT's popularity above that of ACT. [(source)](https://www.orlandosentinel.com/news/education/os-ne-sat-scores-florida-20190924-2ycpuogc2ndkrkwzdrkrjgrg64-story.html)
# - The College Board won a 3-year \$14.3 million bid upon expiry of the ACT exam contract in 30Jun2016 to give its SAT exam to all public high school juniors in Illinois. [(source)](https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html)
# - Nebraska State mandated state accountability testing at the high school level be completed via the ACT test effective spring 2017 to all public school third-year cohort students, except those identified as needing alternate assessment. [(source)](https://www.education.ne.gov/assessment/act/)
# - Ohio state funds either the SAT or ACT test effective Apr2017, with 95% of districts picking the ACT which is $2.50 less expensive than the SAT per test. [(source)](https://www.cleveland.com/metro/2017/04/free_sat_or_act_exams_give_all.html)
# - Rhode Island adopted both the PSAT and SAT tests for high school students in 2017, mandating both tests as a graduation requirement in 2018 as part of the state’s federal education plan. [(source)](https://www.providencejournal.com/story/news/education/2018/10/25/with-sat-required-ri-sees-jump-in-participation-decline-in-scores/9450299007/)
# - West Virginia chose The College Board's SAT as the new statewide standardized test for high school juniors effective spring 2018 because it provides valuable resources at a lower cost than ACT. The contract initially will be for one year, with the option of three 1-year renewals. Students may still use the ACT to qualify for the state's Promise Scholarship. [(source)](https://www.wvgazettemail.com/news/education/wv-chooses-sat-as-new-high-school-standardized-test-for-juniors/article_b60d2618-4943-56f6-b180-4b4442172ef8.html)
# - West Virginia (WV) Governor Jim Justice in 2019 vetoed Senate Bill 624, which would allow counties to use exams other than the SAT as their 11th-grade standardized test, partly because it “directly conflicts” with existing West Virginia law. This probably propelled WV's SAT participation rate to 99% in 2019. [(source)](https://www.wvgazettemail.com/news/education/governor-vetoes-act-choice-bill-citing-law-requiring-same-test-for-4-years/article_17392d95-a8bb-54b3-89a3-ebbd2e18e841.html) and [(source)](https://www.wvea.org/content/governor-vetoes-act-choice-bill-citing-law-requiring-same-test-4-years)
# <br>
#
# - One way to increase SAT participation rate is to cover all or part of exam fees: fee waivers are available for low‐income students, particularly those to whom exam fees would present an undue burden. The College Board also provides a free tool for school counselors to track students’ progress in registering for the SAT and using fee waivers. The College Board reports that fee waivers are more common than ever and supported 23 percent of SAT takers in 2013. However, obtaining a fee waiver does not guarantee test participation. The College Board found that the two most common reasons for test day absenteeism among fee‐waiver recipients were 1) feeling unprepared and 2) not having transportation. Fee‐waiver recipients indicated that the school counselor was the most important influence in deciding whether to register, and they would have been more likely to be present on test day with more encouragement, increased accessibility to test centers, and more preparation." - [(source)](https://www.hanoverresearch.com/media/Best-Practices-to-Increase-SAT-Participation-1.pdf)
# <br>
#
# - States that require the SAT [(source)](https://blog.collegevine.com/states-that-require-sat/):
#  - Colorado high school juniors have been required to take the SAT since the 2016-2017 school year and sophomores are administered the PSAT.
#  - In the 2015-2016 academic year, taking the SAT became a graduation requirement for Connecticut high schoolers, replacing the Smarter Balanced Assessment Consortium (SBAC) exam.
#  - Delaware has provided the SAT free of charge to students since 2011, but in 2016, it replaced its Smarter Balanced Assessment exam with the SAT.
#  - Idaho students must take either the SAT or ACT before the completion of 11th grade—the state offers the SAT for free to high school juniors and the PSAT for free to sophomores.
#  - As of 2017, all Illinois juniors are required to take the SAT.
#  - The SAT is a requirement in the state of Maine—the state still provides the exam for free to third-year high school students.
#  - Michagan moved away from the ACT and began administering the SAT in 2016.
#  - In 2016, New Hampshire transitioned from using Smarter Balanced exams to the SAT.
#  - All Ohio juniors are required to take either a state-funded ACT or SAT exam.
#  - In 2018, the SAT and PSAT became graduation requirements in Rhode Island.
#  - The SAT is mandatory for all West Virginia 11th graders with the exception of students with cognitive disabilities who are given the West Virginia Alternate Assessment.
#  - Florida offers free SAT for Florida Public High School Students, and has compulsory SAT requirement [(source)](https://www.orlandosentinel.com/news/education/os-fsa-algebra-passing-scores-alternative-20180330-story.html).
# <br>
#
# - States that provide SAT for free:
#  - Washington, D.C., does not require high schoolers to take the SAT, but it has provided the exam—as well as the PSAT—for free since 2013.
#  - Oklahoma provides funding for every public school junior to take either the ACT or SAT for free on a specific testing date.
#  - South Carolina does not require either the SAT or the ACT; however, it provides both exams to 11th graders at no cost.
#  - All Tennessee high school students in 11th grade are required to take either the SAT or ACT—school districts are given the choice of which test to provide or may offer both exams.

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Function to return the average of an array of values
def mean(array):
    sum = 0
    for i in array:
        sum += i
    return sum / len(array)

# %%
# Verify function mean() works
mean([1, 2, 3, 4, 5, 6, 7, 8])
# Out:
# 4.5

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Function to return the standard deviation of an array of values
def standard_deviation(array):
    total = 0
    for i in array:
        total += (i - mean(array)) ** 2
    return (1 / len(array) * total) ** 0.5

# %%
# Verify function standard_deviation() works
standard_deviation([1, 2, 3, 4, 5, 6, 7, 8])
# Out:
# 2.29128784747792

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# Function to convert a string to a float after removing the % symbol
def convert_to_float(string):
    return  float(string.replace('%','')) / 100

# %%
# Verify function convert_to_float() works
convert_to_float('12.34%')
# Out:
# 0.1234

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Import all relevant libraries
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# Import the 6 datasets
act2019 = pd.read_csv('../data/act_2019.csv')    # Import 2019 ACT Scores by State
act2018 = pd.read_csv('../data/act_2018.csv')    # Import 2018 ACT Scores by State
act2017 = pd.read_csv('../data/act_2017.csv')    # Import 2017 ACT Scores by State
sat2019 = pd.read_csv('../data/sat_2019.csv')    # Import 2019 SAT Scores by State
sat2018 = pd.read_csv('../data/sat_2018.csv')    # Import 2018 SAT Scores by State
sat2017 = pd.read_csv('../data/sat_2017.csv')    # Import 2017 SAT Scores by State

# %%
# Display the top 5 rows of the act2019 dataset (act_2019.csv)
act2019.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
# Display the top 5 rows of the act2018 dataset (act_2018.csv)
act2018.head()
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
# Display the top 5 rows of the act2017 dataset (act_2017.csv)
act2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
# Display the top 5 rows of the sat2019 dataset (sat_2019.csv)
sat2019.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
# Display the top 5 rows of the sat2018 dataset (sat_2018.csv)
sat2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
# Display the top 5 rows of the sat2017 dataset (sat_2017.csv)
sat2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
# Rename columns of the 6 datasets with lowercase, separated by _, and to reflect the year
act2019.rename(columns = {'State': 'state',
                'Participation': 'act_participation_rate_2019',
                'Composite': 'act_total_score_2019'}, inplace = True)

act2018.rename(columns = {'State': 'state',
                'Participation': 'act_participation_rate_2018',
                'Composite': 'act_total_score_2018'}, inplace = True)

act2017.rename(columns = {'State': 'state',
                'Participation': 'act_participation_rate_2017',
                'English': 'act_english_score_2017',
                'Math': 'act_math_score_2017',
                'Reading': 'act_reading_score_2017',
                'Science': 'act_science_score_2017',
                'Composite': 'act_total_score_2017'}, inplace = True)

sat2019.rename(columns = {'State': 'state',
                'Participation Rate': 'sat_participation_rate_2019',
                'EBRW': 'sat_ebrw_score_2019',
                'Math': 'sat_math_score_2019',
                'Total': 'sat_total_score_2019'}, inplace = True)

sat2018.rename(columns = {'State': 'state',
                'Participation': 'sat_participation_rate_2018',
                'Evidence-Based Reading and Writing': 'sat_ebrw_score_2018',
                'Math': 'sat_math_score_2018',
                'Total': 'sat_total_score_2018'}, inplace = True)

sat2017.rename(columns = {'State': 'state',
                'Participation': 'sat_participation_rate_2017',
                'Evidence-Based Reading and Writing': 'sat_ebrw_score_2017',
                'Math': 'sat_math_score_2017',
                'Total': 'sat_total_score_2017'}, inplace = True)

# %%
# Tuple listing of the ideal full set of 50 U.S. States & District of Columbia
us_states = ('Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 
             'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 
             'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 
             'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 
             'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 
             'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 
             'West Virginia', 'Wisconsin', 'Wyoming')


# Function to compare dataset against "us_states" tuple and
# list Extra items present in dataset that is not in "us_states" tuple, if any
# list Missing items in dataset that is present in "us_states" tuple, if any
# list Duplicated rows in dataset, if any

def check_states(dataset):
    extra = []
    for state in dataset['state']:
        if not(state in us_states):
            extra.append([state])

    missing = []
    for states in us_states:
        if not(states in dataset['state'].unique()):
            missing.append([states])
    
    print(f'For this dataset:')
    print(f'Extra row(s):\n {extra}')  # List of extra U.S. 'state(s)' in dataset, if any
    print(f'Missing row(s):\n {missing}')  # List of missing U.S. 'state(s)' in dataset, if any
    print(f'Duplicated row(s):\n {dataset[dataset.duplicated()]}')  # List duplicated row(s) in dataset, if any
    return


# Function to check column in dataset for values that cannot be converted to float data type 
def invalid_values(dataset_column):
    invalid_value = []
    for i in dataset_column:
        try:
            float(i)
        except:
            invalid_value.append(i)
    if len(invalid_value) == 0:
        return "No invalid values found in this column of the dataset"
    else:
        print(f'Invalid value(s):\n {invalid_value}')
        return


# Function to check column in dataset for values outside acceptable range (i.e. value < minimum or value > maximum) 
def out_of_range(dataset_column, minimum, maximum):
    outside_range = []
    for i in dataset_column:
        if i > maximum or i < minimum: 
            outside_range.append(i)
    if len(outside_range) == 0:
        return "No values outside the acceptable range is found in this column of the dataset"
    else:
        print(f'Value(s) outside acceptable range:\n {outside_range}')
        return

# %%
# List Extra items, Missing items and Duplicated rows of the act2019 dataset (act_2019.csv), if any
check_states(act2019)
# Out:
# For this dataset:
# Extra row(s):
#  [['National']]
# Missing row(s):
#  []
# Duplicated row(s):
#  Empty DataFrame
# Columns: [state, act_participation_rate_2019, act_total_score_2019]
# Index: []

# %%
# List Extra items, Missing items and Duplicated rows of the act2018 dataset (act_2018.csv), if any
check_states(act2018)
# Out:
# For this dataset:
# Extra row(s):
#  [['District of columbia']]
# Missing row(s):
#  [['District of Columbia']]
# Duplicated row(s):
#      state act_participation_rate_2018  act_total_score_2018
# 20  Maine                          7%                  24.0

# %%
# Change case for 'District of Columbia' in act2018 dataset as dataframe.merge() is case-sensitive 
act2018['state'].replace('District of columbia', 'District of Columbia', inplace = True)

# Remove duplicated row in act2018 dataset except for the first occurrence & update index column of dataset accordingly
act2018.drop_duplicates(inplace = True, ignore_index = True)

# %%
# List Extra items, Missing items and Duplicated rows of the act2017 dataset (act_2017.csv), if any
check_states(act2017)
# Out:
# For this dataset:
# Extra row(s):
#  [['National']]
# Missing row(s):
#  []
# Duplicated row(s):
#  Empty DataFrame
# Columns: [state, act_participation_rate_2017, act_english_score_2017, act_math_score_2017, act_reading_score_2017, act_science_score_2017, act_total_score_2017]
# Index: []

# %%
# List Extra items, Missing items and Duplicated rows of the act2019 dataset (sat_2019.csv), if any
check_states(sat2019)
# Out:
# For this dataset:
# Extra row(s):
#  [['Puerto Rico'], ['Virgin Islands']]
# Missing row(s):
#  []
# Duplicated row(s):
#  Empty DataFrame
# Columns: [state, sat_participation_rate_2019, sat_ebrw_score_2019, sat_math_score_2019, sat_total_score_2019]
# Index: []

# %%
# List Extra items, Missing items and Duplicated rows of the act2018 dataset (sat_2018.csv), if any
check_states(sat2018)
# Out:
# For this dataset:
# Extra row(s):
#  []
# Missing row(s):
#  []
# Duplicated row(s):
#  Empty DataFrame
# Columns: [state, sat_participation_rate_2018, sat_ebrw_score_2018, sat_math_score_2018, sat_total_score_2018]
# Index: []

# %%
# List Extra items, Missing items and Duplicated rows of the act2017 dataset (sat_2017.csv), if any
check_states(sat2017)
# Out:
# For this dataset:
# Extra row(s):
#  []
# Missing row(s):
#  []
# Duplicated row(s):
#  Empty DataFrame
# Columns: [state, sat_participation_rate_2017, sat_ebrw_score_2017, sat_math_score_2017, sat_total_score_2017]
# Index: []

# %%
# Merge the 3 ACT dataframes into 1 by using an inner join
# so that we only keep records that are in all 3 ACT dataframes
act1718 = pd.merge(act2017, act2018, on = 'state', how = 'inner')
act_merged = pd.merge(act1718, act2019, on = 'state', how = 'inner')

# Merge the 3 SAT dataframes into 1 by using an inner join
# so that we only keep records that are in all 3 SAT dataframes
sat1718 = pd.merge(sat2017, sat2018, on = 'state', how = 'inner')
sat_merged = pd.merge(sat1718, sat2019, on = 'state', how = 'inner')

# %%
# Display the data types for each feature of the merged ACT dataframe
act_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   state                        51 non-null     object
#  1   act_participation_rate_2017  51 non-null     object
#  2   act_english_score_2017       51 non-null     float64
#  3   act_math_score_2017          51 non-null     float64
#  4   act_reading_score_2017       51 non-null     float64
#  5   act_science_score_2017       51 non-null     float64
#  6   act_total_score_2017         51 non-null     object
#  7   act_participation_rate_2018  51 non-null     object
#  8   act_total_score_2018         51 non-null     float64
#  9   act_participation_rate_2019  51 non-null     object
#  10  act_total_score_2019         51 non-null     float64
# dtypes: float64(6), object(5)
# memory usage: 4.8+ KB

# %%
# Display the data types for each feature of the merged SAT dataframe
sat_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   state                        51 non-null     object
#  1   sat_participation_rate_2017  51 non-null     object
#  2   sat_ebrw_score_2017          51 non-null     int64
#  3   sat_math_score_2017          51 non-null     int64
#  4   sat_total_score_2017         51 non-null     int64
#  5   sat_participation_rate_2018  51 non-null     object
#  6   sat_ebrw_score_2018          51 non-null     int64
#  7   sat_math_score_2018          51 non-null     int64
#  8   sat_total_score_2018         51 non-null     int64
#  9   sat_participation_rate_2019  51 non-null     object
#  10  sat_ebrw_score_2019          51 non-null     int64
#  11  sat_math_score_2019          51 non-null     int64
#  12  sat_total_score_2019         51 non-null     int64
# ...

# %%
# Remove the following 4 unnecessary columns from the merged ACT dataframe:
# act_english_score_2017, act_math_score_2017, act_reading_score_2017, act_science_score_2017
act_merged.drop(columns = ['act_english_score_2017', 'act_math_score_2017', 'act_reading_score_2017', 'act_science_score_2017'], axis = 1, inplace = True)

# Remove the following 6 unnecessary columns from the merged SAT dataframe:
# sat_ebrw_score_2017, sat_math_score_2017, and
# sat_ebrw_score_2018, sat_math_score_2018, and
# sat_ebrw_score_2019, sat_math_score_2019
sat_merged.drop(columns = ['sat_ebrw_score_2017', 'sat_math_score_2017', 'sat_ebrw_score_2018', 'sat_math_score_2018', 'sat_ebrw_score_2019', 'sat_math_score_2019'], axis = 1, inplace = True)

# %%
# Convert percentages to float in merged ACT dataframe using 'convert_to_float' function 
# for columns 'act_participation_rate_2017', 'act_participation_rate_2018' and 'act_participation_rate_2019'
act_merged['act_participation_rate_2017'] = act_merged['act_participation_rate_2017'].apply(convert_to_float)
act_merged['act_participation_rate_2018'] = act_merged['act_participation_rate_2018'].apply(convert_to_float)
act_merged['act_participation_rate_2019'] = act_merged['act_participation_rate_2019'].apply(convert_to_float)

# %%
# List Invalid Values found in 'act_total_score_2017' column of merged ACT dataframe, if any
invalid_values(act_merged['act_total_score_2017'])
# Out:
# Invalid value(s):
#  ['20.2x']

# %%
# Amend Invalid Value found in 'act_total_score_2017' column of merged ACT dataframe above
# Assumption: The extra "x" was unintentionally introduced into dataset without any changes to actual value
act_merged['act_total_score_2017'].replace('20.2x', '20.2', inplace = True)

# Convert 'act_total_score_2017' column of merged ACT dataframe from 'string' to 'float' data type
act_merged['act_total_score_2017'] = act_merged['act_total_score_2017'].astype('float')

# %%
# Verify all values in 'act_participation_rate_2017' column of merged ACT dataframe are within acceptable range
# Participation Rate's acceptable range is between 0% to 100% (i.e. 0 to 1), both inclusive
out_of_range(act_merged['act_participation_rate_2017'], 0, 1)
# Out:
# 'No values outside the acceptable range is found in this column of the dataset'

# %%
# Verify all values in 'act_total_score_2017' column of merged ACT dataframe are within acceptable range
# Total Score's acceptable range for ACT is between 1 to 36, both inclusive
out_of_range(act_merged['act_total_score_2017'], 1, 36)
# Out:
# 'No values outside the acceptable range is found in this column of the dataset'

# %%
# Verify all values in 'act_participation_rate_2018' column of merged ACT dataframe are within acceptable range
# Participation Rate's acceptable range is between 0% to 100% (i.e. 0 to 1), both inclusive
out_of_range(act_merged['act_participation_rate_2018'], 0, 1)
# Out:
# 'No values outside the acceptable range is found in this column of the dataset'

# %%
# Verify all values in 'act_total_score_2018' column of merged ACT dataframe are within acceptable range
# Total Score's acceptable range for ACT is between 1 to 36, both inclusive
out_of_range(act_merged['act_total_score_2018'], 1, 36)
# Out:
# 'No values outside the acceptable range is found in this column of the dataset'

# %%
# Verify all values in 'act_participation_rate_2019' column of merged ACT dataframe are within acceptable range
# Participation Rate's acceptable range is between 0% to 100% (i.e. 0 to 1), both inclusive
out_of_range(act_merged['act_participation_rate_2019'], 0, 1)
# Out:
# 'No values outside the acceptable range is found in this column of the dataset'

# %%
# Verify all values in 'act_total_score_2019' column of merged ACT dataframe are within acceptable range
# Total Score's acceptable range for ACT is between 1 to 36, both inclusive
out_of_range(act_merged['act_total_score_2019'], 1, 36)
# Out:
# 'No values outside the acceptable range is found in this column of the dataset'

# %%
# Convert percentages to float in merged SAT dataframe using 'convert_to_float' function 
# for columns 'sat_participation_rate_2017', 'sat_participation_rate_2018' and 'sat_participation_rate_2019'
sat_merged['sat_participation_rate_2017'] = sat_merged['sat_participation_rate_2017'].apply(convert_to_float)
sat_merged['sat_participation_rate_2018'] = sat_merged['sat_participation_rate_2018'].apply(convert_to_float)
sat_merged['sat_participation_rate_2019'] = sat_merged['sat_participation_rate_2019'].apply(convert_to_float)

# %%
# Verify all values in 'sat_participation_rate_2017' column of merged SAT dataframe are within acceptable range
# Participation Rate's acceptable range is between 0% to 100% (i.e. 0 to 1), both inclusive
out_of_range(sat_merged['sat_participation_rate_2017'], 0, 1)
# Out:
# 'No values outside the acceptable range is found in this column of the dataset'

# %%
# Verify all values in 'sat_total_score_2017' column of merged SAT dataframe are within acceptable range
# Total Score's acceptable range for SAT is between 400 to 1600, both inclusive
out_of_range(sat_merged['sat_total_score_2017'], 400, 1600)
# Out:
# 'No values outside the acceptable range is found in this column of the dataset'

# %%
# Verify all values in 'sat_participation_rate_2018' column of merged SAT dataframe are within acceptable range
# Participation Rate's acceptable range is between 0% to 100% (i.e. 0 to 1), both inclusive
out_of_range(sat_merged['sat_participation_rate_2018'], 0, 1)
# Out:
# 'No values outside the acceptable range is found in this column of the dataset'

# %%
# Verify all values in 'sat_total_score_2018' column of merged SAT dataframe are within acceptable range
# Total Score's acceptable range for SAT is between 400 to 1600, both inclusive
out_of_range(sat_merged['sat_total_score_2018'], 400, 1600)
# Out:
# 'No values outside the acceptable range is found in this column of the dataset'

# %%
# Verify all values in 'sat_participation_rate_2019' column of merged SAT dataframe are within acceptable range
# Participation Rate's acceptable range is between 0% to 100% (i.e. 0 to 1), both inclusive
out_of_range(sat_merged['sat_participation_rate_2019'], 0, 1)
# Out:
# 'No values outside the acceptable range is found in this column of the dataset'

# %%
# Verify all values in 'sat_total_score_2019' column of merged SAT dataframe are within acceptable range
# Total Score's acceptable range for SAT is between 400 to 1600, both inclusive
out_of_range(sat_merged['sat_total_score_2019'], 400, 1600)
# Out:
# 'No values outside the acceptable range is found in this column of the dataset'

# %%
# Verify that data types have been fixed, and 'dirty' rows have been dropped
act_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   state                        51 non-null     object
#  1   act_participation_rate_2017  51 non-null     float64
#  2   act_total_score_2017         51 non-null     float64
#  3   act_participation_rate_2018  51 non-null     float64
#  4   act_total_score_2018         51 non-null     float64
#  5   act_participation_rate_2019  51 non-null     float64
#  6   act_total_score_2019         51 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.2+ KB

# %%
# Verify that data types have been fixed, and 'dirty' rows have been dropped
sat_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   state                        51 non-null     object
#  1   sat_participation_rate_2017  51 non-null     float64
#  2   sat_total_score_2017         51 non-null     int64
#  3   sat_participation_rate_2018  51 non-null     float64
#  4   sat_total_score_2018         51 non-null     int64
#  5   sat_participation_rate_2019  51 non-null     float64
#  6   sat_total_score_2019         51 non-null     int64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 3.2+ KB

# %%
# Create 2 new columns "act_delta_1718" and "act_delta_1819" to calculate change in ACT participation rate
act_merged['act_delta_1718'] = act_merged['act_participation_rate_2018'] - act_merged['act_participation_rate_2017']
act_merged['act_delta_1819'] = act_merged['act_participation_rate_2019'] - act_merged['act_participation_rate_2018']

# %%
# Create 2 new columns "sat_delta_1718" and "sat_delta_1819" to calculate change in SAT participation rate
sat_merged['sat_delta_1718'] = sat_merged['sat_participation_rate_2018'] - sat_merged['sat_participation_rate_2017']
sat_merged['sat_delta_1819'] = sat_merged['sat_participation_rate_2019'] - sat_merged['sat_participation_rate_2018']

# %%
# Display the top 5 rows to see how the merged ACT dataframe looks like now
act_merged.head()
# Out:
#         state  act_participation_rate_2017  act_total_score_2017  \
# 0     Alabama                         1.00                  19.2
# 1      Alaska                         0.65                  19.8
# 2     Arizona                         0.62                  19.7
# 3    Arkansas                         1.00                  19.4
# 4  California                         0.31                  22.8
#
#    act_participation_rate_2018  act_total_score_2018  \
# 0                         1.00                  19.1
# 1                         0.33                  20.8
# 2                         0.66                  19.2
# 3                         1.00                  19.4
# 4                         0.27                  22.7
#
#    act_participation_rate_2019  act_total_score_2019  act_delta_1718  \
# 0                         1.00                  18.9            0.00
# 1                         0.38                  20.1           -0.32
# ...

# %%
# Display the top 5 rows to see how the merged SAT dataframe looks like now
sat_merged.head()
# Out:
#         state  sat_participation_rate_2017  sat_total_score_2017  \
# 0     Alabama                         0.05                  1165
# 1      Alaska                         0.38                  1080
# 2     Arizona                         0.30                  1116
# 3    Arkansas                         0.03                  1208
# 4  California                         0.53                  1055
#
#    sat_participation_rate_2018  sat_total_score_2018  \
# 0                         0.06                  1166
# 1                         0.43                  1106
# 2                         0.29                  1149
# 3                         0.05                  1169
# 4                         0.60                  1076
#
#    sat_participation_rate_2019  sat_total_score_2019  sat_delta_1718  \
# 0                         0.07                  1143            0.01
# 1                         0.41                  1097            0.05
# ...

# %%
# Save the modified merged ACT dataframe as a csv file into the same folder as the original data files
act_merged.to_csv('../data/modified_act_merged.csv', index = False)

# %%
# Save the modified merged SAT dataframe as a csv file into the same folder as the original data files
sat_merged.to_csv('../data/modified_sat_merged.csv', index = False)

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# **Data Dictionaries**:
#
# **For modified ACT dataset    (Filename: 'modified_act_merged.csv')**:
#
# |Feature|Type|Description|
# |---|---|---|
# |state|*object*|States where the high school graduates who took the ACT reside in.|
# |act_participation_rate_2017|*float*|Percentage (in 2 decimal places) of the state's high school graduates who took the ACT in 2017, e.g. 0.25 means 25%.|
# |act_total_score_2017|*integer*|Composite (average of scores for English, Math, Reading, Science) score (1-36) of high school graduates by state in 2017.|
# |act_participation_rate_2018|*float*|Percentage (in 2 decimal places) of the state's high school graduates who took the ACT in 2018, e.g. 0.25 means 25%.|
# |act_total_score_2018|*integer*|Composite (average of scores for English, Math, Reading, Science) score (1-36) of high school graduates by state in 2018.|
# |act_participation_rate_2019|*float*|Percentage (in 2 decimal places) of the state's high school graduates who took the ACT in 2019, e.g. 0.25 means 25%.|
# |act_total_score_2019|*integer*|Composite (average of scores for English, Math, Reading, Science) score (1-36) of high school graduates by state in 2019.|
# |act_delta_1718|*float*|Percentage change (in 2 decimal places) in state's participation rate from 2017 to 2018.|
# |act_delta_1819|*float*|Percentage change (in 2 decimal places) in state's participation rate from 2018 to 2019.|
#
# <BR>
#
# **For modified SAT dataset    (Filename: 'modified_sat_merged.csv')**:
#
# |Feature|Type|Description|
# |---|---|---|
# |state|*object*|States where the high school graduates who took the SAT reside in.|
# |sat_participation_rate_2017|*float*|Percentage (in 2 decimal places) of the state's high school graduates who took the SAT in 2017, e.g. 0.25 means 25%.|
# |sat_total_score_2017|*integer*|Average Total (EBRW + Math) score (400-1,600) of high school graduates by state in 2017.|
# |sat_participation_rate_2018|*float*|Percentage (in 2 decimal places) of the state's high school graduates who took the SAT in 2018, e.g. 0.25 means 25%.|
# |sat_total_score_2018|*integer*|Average Total (EBRW + Math) score (400-1,600) of high school graduates by state in 2018.|
# |sat_participation_rate_2019|*float*|Percentage (in 2 decimal places) of the state's high school graduates who took the SAT in 2019, e.g. 0.25 means 25%.|
# |sat_total_score_2019|*integer*|Average Total (EBRW + Math) score (400-1,600) of high school graduates by state in 2019.|
# |sat_delta_1718|*float*|Percentage change (in 2 decimal places) in state's participation rate from 2017 to 2018.|
# |sat_delta_1819|*float*|Percentage change (in 2 decimal places) in state's participation rate from 2018 to 2019.|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2018, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2018, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
# load the 2 clean/modified dataframes
m_act_merged = pd.read_csv('../data/modified_act_merged.csv')
m_sat_merged = pd.read_csv('../data/modified_sat_merged.csv')

# %%
# Summary Statistics for ACT (Years 2017 to 2019)
m_act_merged.describe()
# Out:
#        act_participation_rate_2017  act_total_score_2017  \
# count                    51.000000             51.000000
# mean                      0.652549             21.519608
# std                       0.321408              2.020695
# min                       0.080000             17.800000
# 25%                       0.310000             19.800000
# 50%                       0.690000             21.400000
# 75%                       1.000000             23.600000
# max                       1.000000             25.500000
#
#        act_participation_rate_2018  act_total_score_2018  \
# count                    51.000000             51.000000
# mean                      0.617255             21.496078
# std                       0.340371              2.111583
# min                       0.070000             17.700000
# 25%                       0.285000             19.950000
# 50%                       0.660000             21.300000
# ...

# %%
# Summary Statistics for SAT (Years 2017 to 2019)
m_sat_merged.describe()
# Out:
#        sat_participation_rate_2017  sat_total_score_2017  \
# count                    51.000000             51.000000
# mean                      0.398039           1126.098039
# std                       0.352766             92.494812
# min                       0.020000            950.000000
# 25%                       0.040000           1055.500000
# 50%                       0.380000           1107.000000
# 75%                       0.660000           1212.000000
# max                       1.000000           1295.000000
#
#        sat_participation_rate_2018  sat_total_score_2018  \
# count                    51.000000             51.000000
# mean                      0.457451           1120.019608
# std                       0.373143             94.155083
# min                       0.020000            977.000000
# 25%                       0.045000           1057.500000
# 50%                       0.520000           1098.000000
# ...

# %%
# Apply the standard_deviation() function to each numeric column in m_act_merged using dictionary comprehension
# if the datatype of the column is a float, apply the standard_deviation() function on the column
# store the output in variable act_sd where keys = column name, value = their respective standard deviation
act_sd = {col: standard_deviation(m_act_merged[col]) for col in m_act_merged.columns 
                               if (m_act_merged[col].dtype == 'float64')}
act_sd
# Out:
# {'act_participation_rate_2017': 0.3182417575123181,
#  'act_total_score_2017': 2.000786081581989,
#  'act_participation_rate_2018': 0.33701735820410317,
#  'act_total_score_2018': 2.090779082141178,
#  'act_participation_rate_2019': 0.3417582373703047,
#  'act_total_score_2019': 2.172901153595978,
#  'act_delta_1718': 0.13324535736570925,
#  'act_delta_1819': 0.05011405676176202}

# %%
# Apply the standard_deviation() function to each numeric column in m_sat_merged using dictionary comprehension
# if the datatype of the column is a float or integer, apply the standard_deviation() function on the column
# store the output in variable sat_sd where keys = column name, value = their respective standard deviation
sat_sd = {col: standard_deviation(m_sat_merged[col]) for col in m_sat_merged.columns 
                               if (m_sat_merged[col].dtype == 'float64') or (m_sat_merged[col].dtype == 'int64')}
sat_sd
# Out:
# {'sat_participation_rate_2017': 0.3492907076664507,
#  'sat_total_score_2017': 91.58351056778743,
#  'sat_participation_rate_2018': 0.3694661922353942,
#  'sat_total_score_2018': 93.22742384464433,
#  'sat_participation_rate_2019': 0.3836584048685726,
#  'sat_total_score_2019': 96.24027185617864,
#  'sat_delta_1718': 0.1809171814070139,
#  'sat_delta_1819': 0.11634111771379803}

# %% [markdown]
# **Investigation of Trends in the Data**

# %%
# States with lowest ACT participation rate in 2017 by sorting
m_act_merged.sort_values('act_participation_rate_2017', ascending = True).head()
# Out:
#             state  act_participation_rate_2017  act_total_score_2017  \
# 19          Maine                         0.08                  24.3
# 29  New Hampshire                         0.18                  25.5
# 7        Delaware                         0.18                  24.1
# 39   Rhode Island                         0.21                  24.0
# 38   Pennsylvania                         0.23                  23.7
#
#     act_participation_rate_2018  act_total_score_2018  \
# 19                         0.07                  24.0
# 29                         0.16                  25.1
# 7                          0.17                  23.8
# 39                         0.15                  24.2
# 38                         0.20                  23.5
#
#     act_participation_rate_2019  act_total_score_2019  act_delta_1718  \
# 19                         0.06                  24.3           -0.01
# 29                         0.14                  25.0           -0.02
# ...

# %% [markdown]
# **Finding #1:**
# - Delaware, Maine, New Hampshire, Pennsylvania, and Rhode Island have consistently been amongst the states with the lowest ACT participation rates for the years 2017 through 2019.
# - Maine had the lowest ACT participation rate for the years 2017 through 2019. Its participation rate continued to decrease by a further 1% in each of the years 2018 and 2019.
# - The states with the lowest ACT participation rates also have state average scores that are above the overall total score (2017 to 2019: 21.5) for each of the years 2017 through 2019, suggesting an inverse relationship between ACT participation rate and ACT scores.

# %%
# States with lowest SAT participation rate in 2017 by sorting
m_sat_merged.sort_values('sat_participation_rate_2017', ascending = True).head()
# Out:
#            state  sat_participation_rate_2017  sat_total_score_2017  \
# 34  North Dakota                         0.02                  1256
# 24   Mississippi                         0.02                  1242
# 15          Iowa                         0.02                  1275
# 25      Missouri                         0.03                  1271
# 44          Utah                         0.03                  1238
#
#     sat_participation_rate_2018  sat_total_score_2018  \
# 34                         0.02                  1283
# 24                         0.03                  1236
# 15                         0.03                  1265
# 25                         0.04                  1262
# 44                         0.04                  1010
#
#     sat_participation_rate_2019  sat_total_score_2019  sat_delta_1718  \
# 34                         0.02                  1263            0.00
# 24                         0.03                  1237            0.01
# ...

# %% [markdown]
# **Finding #2:**
# - Iowa, Mississippi, and North Dakota had the lowest SAT participation rate of 2% in 2017. Their SAT participation rates remained stable over the years, ranging from 2-3%.
# - North Dakota consistently had the lowest SAT participation rate of 2% for the years 2017 through 2019.
# - The states with the lowest SAT participation rates generally also have state average scores that are above the overall total score (2017: 1126 ; 2018: 1120 ; 2019: 1113), suggesting an inverse relationship between SAT participation rate and SAT scores.

# %%
# States with highest ACT participation rate in 2017 by sorting
m_act_merged.sort_values('act_participation_rate_2017', ascending = False).head()
# Out:
#         state  act_participation_rate_2017  act_total_score_2017  \
# 0     Alabama                          1.0                  19.2
# 17   Kentucky                          1.0                  20.0
# 49  Wisconsin                          1.0                  20.5
# 44       Utah                          1.0                  20.3
# 42  Tennessee                          1.0                  19.8
#
#     act_participation_rate_2018  act_total_score_2018  \
# 0                           1.0                  19.1
# 17                          1.0                  20.2
# 49                          1.0                  20.5
# 44                          1.0                  20.4
# 42                          1.0                  19.6
#
#     act_participation_rate_2019  act_total_score_2019  act_delta_1718  \
# 0                           1.0                  18.9             0.0
# 17                          1.0                  19.8             0.0
# ...

# %% [markdown]
# **Finding #3:**
# - Alabama, Kentucky, Tennessee, Utah, and Wisconsin had 100% ACT participation rates across years 2017 through 2019 since ACT is compulsory in these states. [(source)](https://testive.com/state-sat-act/)
# - The states with the highest ACT participation rates also generally have state average scores that are slightly below the overall total score (2017 to 2019: 21.5) for each of the years 2017 through 2019.
# - Reading this together with Finding #1, the 2017 data suggests a potential inverse relationship between ACT participation rate and ACT scores.

# %%
# States with highest SAT participation rate in 2017 by sorting
m_sat_merged.sort_values('sat_participation_rate_2017', ascending = False).head()
# Out:
#                    state  sat_participation_rate_2017  sat_total_score_2017  \
# 8   District of Columbia                         1.00                   950
# 22              Michigan                         1.00                  1005
# 6            Connecticut                         1.00                  1041
# 7               Delaware                         1.00                   996
# 29         New Hampshire                         0.96                  1052
#
#     sat_participation_rate_2018  sat_total_score_2018  \
# 8                          0.92                   977
# 22                         1.00                  1011
# 6                          1.00                  1053
# 7                          1.00                   998
# 29                         0.96                  1063
#
#     sat_participation_rate_2019  sat_total_score_2019  sat_delta_1718  \
# 8                          0.94                   975           -0.08
# ...

# %% [markdown]
# **Finding #4:**
# - Connecticut, Delaware, Michigan, and District of Columbia had the highest SAT participation rate of 100% in 2017. This means that every high school graduate in these states took the SAT.
# - Comparing across years, Connecticut, Delaware, and Michigan had 100% SAT participation rate for all 3 years since SAT is compulsory in these states. [(source)](https://testive.com/state-sat-act/)
# - The SAT participation rate for both District of Columbia and New Hampshire remained stable over the years, consistently > 90%.
# - The states with the highest SAT participation rate also generally have state average scores that are below the overall aggregated score (2017: 1,126 ; 2018: 1,120 ; 2019: 1,113).
# - Reading this together with Finding #2, the 2017 data suggests a potential inverse relationship between SAT participation rate and SAT scores.

# %%
# States with lowest ACT participation rate in 2018 by sorting
m_act_merged.sort_values('act_participation_rate_2018', 
                         ascending = True)[['state', 'act_participation_rate_2018', 'act_total_score_2018', 
                                            'act_participation_rate_2019', 'act_total_score_2019', 
                                            'act_delta_1819']].head()
# Out:
#             state  act_participation_rate_2018  act_total_score_2018  \
# 19          Maine                         0.07                  24.0
# 39   Rhode Island                         0.15                  24.2
# 29  New Hampshire                         0.16                  25.1
# 7        Delaware                         0.17                  23.8
# 38   Pennsylvania                         0.20                  23.5
#
#     act_participation_rate_2019  act_total_score_2019  act_delta_1819
# 19                         0.06                  24.3           -0.01
# 39                         0.12                  24.7           -0.03
# 29                         0.14                  25.0           -0.02
# 7                          0.13                  24.1           -0.04
# 38                         0.17                  23.6           -0.03

# %%
# Top 5 states with highest ACT participation rate in 2018 by sorting
m_act_merged.sort_values('act_participation_rate_2018', 
                         ascending = False)[['state', 'act_participation_rate_2018', 'act_total_score_2018', 
                                            'act_participation_rate_2019', 'act_total_score_2019', 
                                            'act_delta_1819']].head()
# Out:
#         state  act_participation_rate_2018  act_total_score_2018  \
# 0     Alabama                          1.0                  19.1
# 17   Kentucky                          1.0                  20.2
# 49  Wisconsin                          1.0                  20.5
# 44       Utah                          1.0                  20.4
# 42  Tennessee                          1.0                  19.6
#
#     act_participation_rate_2019  act_total_score_2019  act_delta_1819
# 0                           1.0                  18.9             0.0
# 17                          1.0                  19.8             0.0
# 49                          1.0                  20.3             0.0
# 44                          1.0                  20.3             0.0
# 42                          1.0                  19.4             0.0

# %% [markdown]
# **Finding #5:**
# - The 2 blocks of codes above shows the states with the lowest and highest ACT participation rates in 2018 respectively. Generally, states with lowest ACT participation rates have state average score that are above the overall aggregated score (2018: 21.5) while states with the highest ACT participation rates generally have state average score that are below the overall aggregated score in 2018. Similarly, the 2018 data suggests an inverse relationship between ACT participation rate and ACT score.
# - Since ACT is compulsory in Alabama, Kentucky, Tennessee, Utah, and Wisconsin, ACT participation rates remained unchanged at 100% for both 2018 and 2019. [(source)](https://testive.com/state-sat-act/)
# - However, ACT participation rates of Delaware, Maine, New Hampshire, Pennsylvania, and Rhode Island continues to decline by at least 1%.

# %%
# States with lowest SAT participation rate in 2018 by sorting
m_sat_merged.sort_values('sat_participation_rate_2018', 
                         ascending = True)[['state', 'sat_participation_rate_2018', 'sat_total_score_2018', 
                                            'sat_participation_rate_2019', 'sat_total_score_2019', 
                                            'sat_delta_1819']].head()
# Out:
#            state  sat_participation_rate_2018  sat_total_score_2018  \
# 34  North Dakota                         0.02                  1283
# 50       Wyoming                         0.03                  1257
# 41  South Dakota                         0.03                  1240
# 27      Nebraska                         0.03                  1252
# 49     Wisconsin                         0.03                  1294
#
#     sat_participation_rate_2019  sat_total_score_2019  sat_delta_1819
# 34                         0.02                  1263             0.0
# 50                         0.03                  1238             0.0
# 41                         0.03                  1268             0.0
# 27                         0.03                  1260             0.0
# 49                         0.03                  1283             0.0

# %%
# Top 5 states with highest SAT participation rate in 2018 by sorting
m_sat_merged.sort_values('sat_participation_rate_2018', 
                         ascending = False)[['state', 'sat_participation_rate_2018', 'sat_total_score_2018', 
                                            'sat_participation_rate_2019', 'sat_total_score_2019', 
                                            'sat_delta_1819']].head()
# Out:
#           state  sat_participation_rate_2018  sat_total_score_2018  \
# 5      Colorado                          1.0                  1025
# 6   Connecticut                          1.0                  1053
# 7      Delaware                          1.0                   998
# 22     Michigan                          1.0                  1011
# 12        Idaho                          1.0                  1001
#
#     sat_participation_rate_2019  sat_total_score_2019  sat_delta_1819
# 5                           1.0                  1024             0.0
# 6                           1.0                  1046             0.0
# 7                           1.0                   985             0.0
# 22                          1.0                  1003             0.0
# 12                          1.0                   993             0.0

# %% [markdown]
# **Finding #6:**
# - The 2 blocks of codes above shows the states with the lowest and highest SAT participation rates in 2018 respectively. Generally, states with lowest SAT participation rates have state average score that are above the overall aggregated score (2018: 1120). In contrast, states with the highest SAT participation rates generally have state average score that are below the overall aggregated score in 2018. Similarly, the 2018 data suggests an inverse relationship between SAT participation rate and SAT score.
# - Since SAT is also compulsory in Colorado, Connecticut, Delaware, Idaho, and Michigan, SAT participation rates remained unchanged at 100% for both 2018 and 2019. [(source)](https://testive.com/state-sat-act/)
# - SAT participation rates of Nebraska, North Dakota, South Dakota, Wisconsin, and Wyoming remained unchanged from 2018 to 2019 too.

# %%
# Top 5 states with lowest ACT participation rate in 2019 by sorting
m_act_merged.sort_values('act_participation_rate_2019', 
                         ascending = True)[['state', 'act_participation_rate_2019', 'act_total_score_2019']].head()
# Out:
#             state  act_participation_rate_2019  act_total_score_2019
# 19          Maine                         0.06                  24.3
# 39   Rhode Island                         0.12                  24.7
# 7        Delaware                         0.13                  24.1
# 29  New Hampshire                         0.14                  25.0
# 38   Pennsylvania                         0.17                  23.6

# %%
# Top 5 states with highest ACT participation rate in 2019 by sorting
m_act_merged.sort_values('act_participation_rate_2019', 
                         ascending = False)[['state', 'act_participation_rate_2019', 'act_total_score_2019']].head()
# Out:
#         state  act_participation_rate_2019  act_total_score_2019
# 0     Alabama                          1.0                  18.9
# 17   Kentucky                          1.0                  19.8
# 49  Wisconsin                          1.0                  20.3
# 44       Utah                          1.0                  20.3
# 42  Tennessee                          1.0                  19.4

# %% [markdown]
# **Finding #7:**
# - For completeness, we also check if the inverse relationship between ACT participation rate and ACT score exist using the 2019 data. From the 2 blocks of codes above, we see that states with the lowest ACT participation rate have higher ACT scores than the overall aggregated score (2019: 21.5), and states with the highest ACT participation rate have lower ACT scores than the overall aggregated score.

# %%
# Top 5 states with lowest SAT participation rate in 2019 by sorting
m_sat_merged.sort_values('sat_participation_rate_2019', 
                         ascending = True)[['state', 'sat_participation_rate_2019', 'sat_total_score_2019']].head()
# Out:
#            state  sat_participation_rate_2019  sat_total_score_2019
# 34  North Dakota                         0.02                  1263
# 50       Wyoming                         0.03                  1238
# 41  South Dakota                         0.03                  1268
# 27      Nebraska                         0.03                  1260
# 49     Wisconsin                         0.03                  1283

# %%
# Top 5 states with highest SAT participation rate in 2019 by sorting
m_sat_merged.sort_values('sat_participation_rate_2019', 
                         ascending = False)[['state', 'sat_participation_rate_2019', 'sat_total_score_2019']].head()
# Out:
#            state  sat_participation_rate_2019  sat_total_score_2019
# 39  Rhode Island                          1.0                   995
# 13      Illinois                          1.0                  1013
# 22      Michigan                          1.0                  1003
# 5       Colorado                          1.0                  1024
# 6    Connecticut                          1.0                  1046

# %% [markdown]
# **Finding #8:**
# - Similarly, for completeness, we also check if the inverse relationship between SAT participation rate and SAT score exist using the 2019 data. From the 2 blocks of codes above, we see that states with the lowest SAT participation rate have higher SAT scores than the overall aggregated score (2019: 1113), and states with the highest SAT participation rate have lower SAT scores than the overal aggregated score.

# %%
# Filter for states with >5 percentage point decrease in ACT participation rate between 2017-2018, or 2018-2019
m_act_merged.loc[(m_act_merged['act_delta_1718'] < -0.05) | (m_act_merged['act_delta_1819'] < -0.05)].sort_values(
    'act_delta_1718', ascending = True)[['state', 'act_participation_rate_2017', 'act_participation_rate_2018',
                                         'act_participation_rate_2019', 'act_delta_1718', 'act_delta_1819']]
# Out:
#              state  act_participation_rate_2017  act_participation_rate_2018  \
# 5         Colorado                         1.00                         0.30
# 13        Illinois                         0.93                         0.43
# 1           Alaska                         0.65                         0.33
# 9          Florida                         0.73                         0.66
# 22        Michigan                         0.29                         0.22
# 39    Rhode Island                         0.21                         0.15
# 48   West Virginia                         0.69                         0.65
# 30      New Jersey                         0.34                         0.31
# 11          Hawaii                         0.90                         0.89
# 25        Missouri                         1.00                         1.00
# 40  South Carolina                         1.00                         1.00
# ...

# %% [markdown]
# **Finding #9:**
# - Colorado state mandated SAT for all high school juniors effective 11Apr2017, resulting in drastic drop of its ACT participation rate to 30% and lower beyond 2017. [(source)](https://testive.com/colorado-sat-change-2017/)
# - The College Board won a 3-year $14.3 million bid upon expiry of the ACT exam contract in 30Jun2016 to give its SAT exam to all public high school juniors in Illinois, resulting in drastic drop of Illinois' ACT participation rate to 43% and lower beyond 2017. [(source)](https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html)
# - Alaska's high school students no longer required by state law to take the SAT, ACT or WorkKeys test to get their diplomas as the law expired 30Jun2016. This resulted in a drastic drop of Alaska's ACT participation rate to 65% and lower for 2017 and 2018. Alaska's ACT participation rate increased slightly by 5% to 38% in 2019. [(source)](https://www.adn.com/alaska-news/education/2016/06/30/students-no-longer-need-national-tests-to-graduate/)
# - More Florida students took the SAT in 2018 than ever before, pushed by free test sessions at their schools, resulting in drop of its ACT participation rate to 66% and lower beyond 2017. [(source)](https://www.orlandosentinel.com/news/education/os-ne-act-sat-florida-scores-20181024-story.html)

# %%
# Filter for states with >5 percentage point decrease in SAT participation rate between 2017-2018, or 2018-2019
m_sat_merged.loc[(m_sat_merged['sat_delta_1718'] < -0.05) | (m_sat_merged['sat_delta_1819'] < -0.05)].sort_values(
    'sat_delta_1718', ascending = True)[['state', 'sat_participation_rate_2017', 'sat_participation_rate_2018',
                                         'sat_participation_rate_2019', 'sat_delta_1718', 'sat_delta_1819']]
# Out:
#                   state  sat_participation_rate_2017  \
# 9               Florida                         0.83
# 8  District of Columbia                         1.00
#
#    sat_participation_rate_2018  sat_participation_rate_2019  sat_delta_1718  \
# 9                         0.56                         1.00           -0.27
# 8                         0.92                         0.94           -0.08
#
#    sat_delta_1819
# 9            0.44
# 8            0.02

# %% [markdown]
# **Finding #10:**
# - Florida and District of Columbia (DC)'s SAT participation rate dropped by more than 5% between 2017 and 2018. SAT participation rate in Florida seems to flucuate over the years, with a 27% drop from 83% in 2017 to 56% in 2018, then a 44% increase to full SAT participation in 2019. For DC, even though there was a drop, the SAT participation rate remains high (>90%) over the years.

# %%
# Filter for states with >5 percentage point increase in ACT participation rate between 2017-2018
m_act_merged.loc[(m_act_merged['act_delta_1718'] > 0.05)].sort_values('act_delta_1718', 
    ascending = False)[['state', 'act_participation_rate_2017', 'act_participation_rate_2018', 'act_delta_1718']]
# Out:
#        state  act_participation_rate_2017  act_participation_rate_2018  \
# 35      Ohio                         0.75                          1.0
# 27  Nebraska                         0.84                          1.0
#
#     act_delta_1718
# 35            0.25
# 27            0.16

# %% [markdown]
# **Finding #11:**
# - Ohio state funds either the SAT or ACT test effective Apr2017, with 95% of districts picking the ACT which is $2.50 less expensive than the SAT per test. [(source)](https://www.cleveland.com/metro/2017/04/free_sat_or_act_exams_give_all.html)
# - Nebraska State mandated state accountability testing at the high school level be completed via the ACT test effective spring 2017 to all public school third-year cohort students, except those identified as needing alternate assessment. [(source)](https://www.education.ne.gov/assessment/act/)
# - These probably led to the rise in ACT participation rate to 100% for both Ohio and Nebraska in 2018.

# %%
# Filter for states with >5 percentage point increase in SAT participation rate between 2017-2018
m_sat_merged.loc[(m_sat_merged['sat_delta_1718'] > 0.05)].sort_values('sat_delta_1718', 
    ascending = False)[['state', 'sat_participation_rate_2017', 'sat_participation_rate_2018', 'sat_delta_1718']]
# Out:
#             state  sat_participation_rate_2017  sat_participation_rate_2018  \
# 13       Illinois                         0.09                         0.99
# 5        Colorado                         0.11                         1.00
# 39   Rhode Island                         0.71                         0.97
# 48  West Virginia                         0.14                         0.28
# 30     New Jersey                         0.70                         0.82
# 32       New York                         0.67                         0.79
# 10        Georgia                         0.61                         0.70
# 20       Maryland                         0.69                         0.76
# 4      California                         0.53                         0.60
# 12          Idaho                         0.93                         1.00
# 35           Ohio                         0.12                         0.18
#
#     sat_delta_1718
# 13            0.90
# ...

# %% [markdown]
# **Finding #12:**
# - As highlighted in Finding #9 above, both Colorado [(source)](https://testive.com/colorado-sat-change-2017/) and Illinois [(source)](https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html) favoured SAT over ACT.
# - Rhode Island adopted both the PSAT and SAT tests for high school students in 2017, mandating both tests as a graduation requirement in 2018 as part of the state’s federal education plan. [(source)](https://www.providencejournal.com/story/news/education/2018/10/25/with-sat-required-ri-sees-jump-in-participation-decline-in-scores/9450299007/)
# - West Virginia chose The College Board's SAT as the new statewide standardized test for high school juniors effective spring 2018 because it provides valuable resources at a lower cost than ACT. The contract initially will be for one year, with the option of three 1-year renewals. Students may still use the ACT to qualify for the state's Promise Scholarship. [(source)](https://www.wvgazettemail.com/news/education/wv-chooses-sat-as-new-high-school-standardized-test-for-juniors/article_b60d2618-4943-56f6-b180-4b4442172ef8.html)

# %%
# Filter for states with >5 percentage point increase in ACT participation rate between 2018-2019
m_act_merged.loc[(m_act_merged['act_delta_1819'] > 0.05)].sort_values('act_delta_1819', 
    ascending = False)[['state', 'act_participation_rate_2018', 'act_participation_rate_2019', 'act_delta_1819']]
# Out:
#      state  act_participation_rate_2018  act_participation_rate_2019  \
# 2  Arizona                         0.66                         0.73
#
#    act_delta_1819
# 2            0.07

# %% [markdown]
# **Finding #13:**
# - Arizona allows for its 55 public schools to measure high school students’ proficiency in Arizona academic standards with the ACT or SAT effective 2019 instead of AzMERIT. 44 of these 55 schools chose ACT over SAT, citing reasons of lesser time needed to take the ACT (vs AzMERIT), greater student ownership, value and meaning. This probably led to the rise in ACT participation rate by 7% from 2018 in 2019. [(source)](https://azednews.com/why-some-schools-chose-the-act-or-sat-over-azmerit/)

# %%
# Filter for states with >5 percentage point increase in SAT participation rate between 2018-2019
m_sat_merged.loc[(m_sat_merged['sat_delta_1819'] > 0.05)].sort_values('sat_delta_1819', 
    ascending = False)[['state', 'sat_participation_rate_2018', 'sat_participation_rate_2019', 'sat_delta_1819']]
# Out:
#              state  sat_participation_rate_2018  sat_participation_rate_2019  \
# 48   West Virginia                         0.28                         0.99
# 9          Florida                         0.56                         1.00
# 36        Oklahoma                         0.08                         0.22
# 40  South Carolina                         0.55                         0.68
# 20        Maryland                         0.76                         0.82
#
#     sat_delta_1819
# 48            0.71
# 9             0.44
# 36            0.14
# 40            0.13
# 20            0.06

# %% [markdown]
# **Finding #14:**
# - Further to what has been highlighted in Finding #12 above, West Virginia (WV) Governor Jim Justice in 2019 vetoed Senate Bill 624, which would allow counties to use exams other than the SAT as their 11th-grade standardized test, partly because it “directly conflicts” with existing West Virginia law. This probably propelled WV's SAT participation rate to 99% in 2019. [(source)](https://www.wvgazettemail.com/news/education/governor-vetoes-act-choice-bill-citing-law-requiring-same-test-for-4-years/article_17392d95-a8bb-54b3-89a3-ebbd2e18e841.html) and [(source)](https://www.wvea.org/content/governor-vetoes-act-choice-bill-citing-law-requiring-same-test-4-years)
# - In Florida, more students are taking the SAT exam largely because of “SAT school day” programs that allow for taking the exam during the week, at their school, free of charge. Many Florida school districts now offer such programs, driving up SAT's popularity above that of ACT. [(source)](https://www.orlandosentinel.com/news/education/os-ne-sat-scores-florida-20190924-2ycpuogc2ndkrkwzdrkrjgrg64-story.html)

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# Plot a heatmap to check correlation of all numeric features in ACT dataset
plt.rcParams['figure.figsize'] = 15,6
plt.rcParams['font.size'] = 14

matrix = np.triu(m_act_merged.corr()) # Returns the lower triangle of any matrix
heatmap = sns.heatmap(m_act_merged.corr(), annot = True, vmin = -1, vmax = 1, center = 0,
                      cbar = True, cmap = 'PuBu', linewidths = 2, linecolor = 'white', mask = matrix);

# Setting the labels
heatmap.set_title('Correlation Between All Numeric Features in ACT Dataset');

# %% [markdown]
# **Interpretation**:
# - The above heatmap shows the correlation between all numeric features in the ACT dataset. There is generally a negative correlation between ACT participation rate and total score (r ≤ -0.86). This means that when a state has a higher ACT participation rate, the average total scores tend to be lower when compared to states with a lower ACT participation rate.
# - ACT participation rate in a specific year is positively correlated (r ≥ 0.9) to the participation rate for other years. This means that if the participation rate of a state is high in 2017, the participation rate will likely be high in 2018 and 2019 too.
# - Similarly, ACT total score in a specific year is positively correlated (r ≥ 0.93) to the SAT total score for other years. This means that if the ACT total score of a state is high in 2017, the ACT total score will likely be high in 2018 and 2019 too.

# %%
# Plot a heatmap to check correlation of all numeric features in SAT dataset
plt.rcParams['figure.figsize'] = 15,6
plt.rcParams['font.size'] = 14

matrix = np.triu(m_sat_merged.corr()) # Returns the lower triangle of any matrix
heatmap = sns.heatmap(m_sat_merged.corr(), annot = True, vmin = -1, vmax = 1, center = 0,
                      cbar = True, cmap = 'PuBu', linewidths = 2, linecolor = 'white', mask = matrix);

# Setting the labels
heatmap.set_title('Correlation Between All Numeric Features in SAT Dataset');

# %% [markdown]
# **Interpretation**:
# - The above heatmap shows the correlation between all numeric features in the SAT dataset. There is generally a negative correlation between SAT participation rate and total score (r ≤ -0.79). This means that when a state has a higher SAT participation rate, the average total scores tend to be lower when compared to states with a lower SAT participation rate.
# - SAT participation rate in a specific year is positively correlated (r ≥ 0.84) to the participation rate for other years. This means that if the participation rate of a state is high in 2017, the participation rate will likely be high in 2018 and 2019 too.
# - Similarly, SAT total score in a specific year is positively correlated (r ≥ 0.85) to the SAT total score for other years. This means that if the SAT total score of a state is high in 2017, the SAT total score will likely be high in 2018 and 2019 too.

# %%
# Check the relationship between every pair of variables from ACT dataset
pair = sns.pairplot(m_act_merged);
pair.fig.suptitle("Relationship of All Numeric Features in ACT Dataset", y = 1, fontsize = 16);

# %% [markdown]
# **Interpretation**:
# - The above image shows the relationship of all the numeric features of the ACT dataset, via a scatter plot. It is similar to the heatmap on correlation, but it provides the spread of data instead of the correlation coefficients.

# %%
# Check the relationship between every pair of variables from SAT dataset
pair = sns.pairplot(m_sat_merged);
pair.fig.suptitle("Relationship of All Numeric Features in SAT Dataset", y = 1, fontsize = 16);

# %% [markdown]
# **Interpretation**:
# - The above image shows the relationship of all the numeric features of the SAT dataset, via a scatter plot. It is similar to the heatmap on correlation, but it provides the spread of data instead of the correlation coefficients.

# %%
# Summary statistics to compare mean/median to check if ACT data is skewed
m_act_merged.describe()
# Out:
#        act_participation_rate_2017  act_total_score_2017  \
# count                    51.000000             51.000000
# mean                      0.652549             21.519608
# std                       0.321408              2.020695
# min                       0.080000             17.800000
# 25%                       0.310000             19.800000
# 50%                       0.690000             21.400000
# 75%                       1.000000             23.600000
# max                       1.000000             25.500000
#
#        act_participation_rate_2018  act_total_score_2018  \
# count                    51.000000             51.000000
# mean                      0.617255             21.496078
# std                       0.340371              2.111583
# min                       0.070000             17.700000
# 25%                       0.285000             19.950000
# 50%                       0.660000             21.300000
# ...

# %%
# Plot 3 Histograms side by side to show the ACT participation rate across states from 2017 to 2019
act_fig, act_axes = plt.subplots(1, 3, figsize=(18, 8), sharey=True)
act_fig.suptitle('ACT Participation Rates from 2017 to 2019', fontsize = 18, fontweight = 'bold')
act_hist_2017 = sns.histplot(data = m_act_merged, x = 'act_participation_rate_2017', bins = 20, color = '#C5F9D7', ax = act_axes[0])
act_hist_2018 = sns.histplot(data = m_act_merged, x = 'act_participation_rate_2018', bins = 20, color = '#F7D486', ax = act_axes[1])
act_hist_2019 = sns.histplot(data = m_act_merged, x = 'act_participation_rate_2019', bins = 20, color = '#F27A7D', ax = act_axes[2])

# Include horizontal grid lines for greater ease in reading the values (OPTIONAL)
# act_hist_2017.grid(axis='y')
# act_hist_2018.grid(axis='y')
# act_hist_2019.grid(axis='y')

# Setting the labels for each ACT subplot
act_hist_2017.set_xlabel('2017 ACT Participation Rate')
act_hist_2017.set_ylabel('Number of States')
act_hist_2018.set_xlabel('2018 ACT Participation Rate')
act_hist_2018.set_ylabel('Number of States')
act_hist_2019.set_xlabel('2019 ACT Participation Rate')
act_hist_2019.set_ylabel('Number of States')

# Draw a dashed Mean line for each ACT subplot
act_axes[0].axvline(m_act_merged['act_participation_rate_2017'].mean(), linestyle = 'dashed', label = 'mean')
act_axes[1].axvline(m_act_merged['act_participation_rate_2018'].mean(), linestyle = 'dashed', label = 'mean')
act_axes[2].axvline(m_act_merged['act_participation_rate_2019'].mean(), linestyle = 'dashed', label = 'mean')

# Draw a solid Median line for each ACT subplot
act_axes[0].axvline(m_act_merged['act_participation_rate_2017'].median(), label = 'median')
act_axes[1].axvline(m_act_merged['act_participation_rate_2018'].median(), label = 'median')
act_axes[2].axvline(m_act_merged['act_participation_rate_2019'].median(), label = 'median')

# %% [markdown]
# **Interpretation**:
# - The 3 plots above show the spread in the state average ACT participation rate for years 2017 to 2019.
#  - In both the 2017 and 2018 plots, since the mean (dotted vertical line) is to the left of the median (solid vertical line), the data is negatively skewed (i.e. mean 0.65 < median 0.69 in 2017 ; mean 0.62 < median 0.66 in 2018). This implies that many of the states have high ACT participation rate, but there are some with low ACT participation rate which resulted in a longer tail on the left.
#  - However, in the 2019 plot, the mean has switched to the right of the median (i.e. mean 0.59 > 0.54 in 2019), the data for 2019 has become positively skewed instead.
#  - Since both the mean and median have been decreasing from 2017 to 2019, this means that the overall ACT participation rate have been decreasing. Notably, while there is a slight increase in the number of states with 100% ACT participation rate in 2018 from 2017, this is followed by a noticeable decrease in the number of states with 100% ACT participation rate in 2019 from 2018.
#  - The distribution of the original data for each year is not normally distributed since the plots are skewed/asymmetrical and do not resemble the typical bell curve. Nevertheless, based on the Central Limit Theorem, if we take a sample of more than 30, the distribution of the sample means will be approximately normally distributed.

# %%
# Summary statistics to compare mean/median to check if SAT data is skewed
m_sat_merged.describe()
# Out:
#        sat_participation_rate_2017  sat_total_score_2017  \
# count                    51.000000             51.000000
# mean                      0.398039           1126.098039
# std                       0.352766             92.494812
# min                       0.020000            950.000000
# 25%                       0.040000           1055.500000
# 50%                       0.380000           1107.000000
# 75%                       0.660000           1212.000000
# max                       1.000000           1295.000000
#
#        sat_participation_rate_2018  sat_total_score_2018  \
# count                    51.000000             51.000000
# mean                      0.457451           1120.019608
# std                       0.373143             94.155083
# min                       0.020000            977.000000
# 25%                       0.045000           1057.500000
# 50%                       0.520000           1098.000000
# ...

# %%
# Plot 3 Histograms side by side to show the SAT participation rate across states from 2017 to 2019
sat_fig, sat_axes = plt.subplots(1, 3, figsize=(18, 8), sharey=True)
sat_fig.suptitle('SAT Participation Rates from 2017 to 2019', fontsize = 18, fontweight = 'bold')
sat_hist_2017 = sns.histplot(data = m_sat_merged, x = 'sat_participation_rate_2017', bins = 20, color = '#C5F9D7', ax = sat_axes[0])
sat_hist_2018 = sns.histplot(data = m_sat_merged, x = 'sat_participation_rate_2018', bins = 20, color = '#F7D486', ax = sat_axes[1])
sat_hist_2019 = sns.histplot(data = m_sat_merged, x = 'sat_participation_rate_2019', bins = 20, color = '#F27A7D', ax = sat_axes[2])

# Include horizontal grid lines for greater ease in reading the values (OPTIONAL)
# sat_hist_2017.grid(axis='y')
# sat_hist_2018.grid(axis='y')
# sat_hist_2019.grid(axis='y')

# Setting the labels for each SAT subplot
sat_hist_2017.set_xlabel('2017 SAT Participation Rate')
sat_hist_2017.set_ylabel('Number of States')
sat_hist_2018.set_xlabel('2018 SAT Participation Rate')
sat_hist_2018.set_ylabel('Number of States')
sat_hist_2019.set_xlabel('2019 SAT Participation Rate')
sat_hist_2019.set_ylabel('Number of States')

# Draw a dashed Mean line for each SAT subplot
sat_axes[0].axvline(m_sat_merged['sat_participation_rate_2017'].mean(), linestyle = 'dashed', label = 'mean')
sat_axes[1].axvline(m_sat_merged['sat_participation_rate_2018'].mean(), linestyle = 'dashed', label = 'mean')
sat_axes[2].axvline(m_sat_merged['sat_participation_rate_2019'].mean(), linestyle = 'dashed', label = 'mean')

# Draw a solid Median line for each SAT subplot
sat_axes[0].axvline(m_sat_merged['sat_participation_rate_2017'].median(), label = 'median')
sat_axes[1].axvline(m_sat_merged['sat_participation_rate_2018'].median(), label = 'median')
sat_axes[2].axvline(m_sat_merged['sat_participation_rate_2019'].median(), label = 'median')

# %% [markdown]
# **Interpretation**:
# - The 3 plots above show the spread in the state average SAT participation rate for years 2017 to 2019.
#  - In the 2017 plot, since the mean (dotted vertical line) is slightly to the right of the median (solid vertical line), the data is positively skewed (i.e. mean 0.40 > median 0.38). This implies that many of the states have low SAT participation rate, but there are some with high SAT participation rate which resulted in a longer tail on the right.
#  - However, in both the 2018 and 2019 plots, the mean has switched to the left of the median (i.e. mean 0.46 < 0.52 in 2018 ; mean 0.49 < 0.54 in 2019), the data for these 2 years have become negatively skewed instead.
#  - Since both the mean and median have been increasing from 2017 to 2019, this means that the overall SAT participation rate have been increasing. Notably, there is a noticeable increase in the number of states with 100% SAT participation rate in 2018 from 2017 and a noticeable decrease in the number of states with 0% SAT participation rate in 2019 from 2018.
#  - The distribution of the original data for each year is not normally distributed since the plots are skewed/asymmetrical and do not resemble the typical bell curve. Nevertheless, based on the Central Limit Theorem, if we take a sample of more than 30, the distribution of the sample means will be approximately normally distributed.

# %%
# Filter ACT dataset for states with > 90% ACT participation rate yearly
act_hi_participation_rate = m_act_merged.loc[(m_act_merged['act_participation_rate_2017'] > 0.9) & 
                                             (m_act_merged['act_participation_rate_2018'] > 0.9) &
                                             (m_act_merged['act_participation_rate_2019'] > 0.9)]

# Check the size of the dataframe
act_hi_participation_rate.shape
# Out:
# (15, 9)

# %%
# Filter ACT dataset for states with < 10% ACT participation rate yearly
act_lo_participation_rate = m_act_merged.loc[(m_act_merged['act_participation_rate_2017'] < 0.1) & 
                                             (m_act_merged['act_participation_rate_2018'] < 0.1) &
                                             (m_act_merged['act_participation_rate_2019'] < 0.1)]

# Check the size of the dataframe
act_lo_participation_rate.shape
# Out:
# (1, 9)

# %%
# Boxplot to show the relationship between average total score for all states 
# vs state with < 10% ACT participation rate vs state with > 90% ACT participation rate

# Create a dictionary where keys are the years, and values are the average total scores per state
act_ts = {'act_2017': m_act_merged['act_total_score_2017'], 
          'act_2018': m_act_merged['act_total_score_2018'], 
          'act_2019': m_act_merged['act_total_score_2019']}

# Create a dictionary where keys are the years, and 
# values are the average total scores per state for state < 10% ACT participation rate
act_lo_ts = {'act_2017': act_lo_participation_rate['act_total_score_2017'], 
             'act_2018': act_lo_participation_rate['act_total_score_2018'], 
             'act_2019': act_lo_participation_rate['act_total_score_2019']}

# Create a dictionary where keys are the years, and 
# values are the average total scores per state for state > 90% ACT participation rate
act_hi_ts = {'act_2017': act_hi_participation_rate['act_total_score_2017'], 
             'act_2018': act_hi_participation_rate['act_total_score_2018'], 
             'act_2019': act_hi_participation_rate['act_total_score_2019']}

# Plot them as 3 subplots
plt.rcParams['font.size'] = 20
fig, (ax1, ax2, ax3) = plt.subplots(nrows = 3, ncols = 1, figsize = (15, 24))
act_ts_plot = ax1.boxplot(act_ts.values(),
                         patch_artist = True,
                         labels = ['2017', '2018', '2019'])
ax1.set_title('State Average Total Score for ACT by Years',
             {'fontsize': 20, 'fontweight': 'bold'})
ax1.set_xlabel('Year')
ax1.set_ylabel('Total ACT Score')
# set consistent y limit to see the difference across 3 plots
ax1.set_ylim([16, 30])

act_lo_ts_plot = ax2.boxplot(act_lo_ts.values(), 
                             patch_artist = True,
                             labels = ['2017', '2018', '2019'])
ax2.set_title('State (< 10% Participation Rate) Average Total Score for ACT by Years',
             {'fontsize': 20, 'fontweight': 'bold'})
ax2.set_xlabel('Year')
ax2.set_ylabel('Total ACT Score')
# set consistent y limit to see the difference across 3 plots
ax2.set_ylim([16, 30])

act_hi_ts_plot = ax3.boxplot(act_hi_ts.values(), 
                             patch_artist = True,
                             labels = ['2017', '2018', '2019'])
ax3.set_title('State (> 90% Participation Rate) Average Total Score for ACT by Years',
             {'fontsize': 20, 'fontweight': 'bold'})
ax3.set_xlabel('Year')
ax3.set_ylabel('Total ACT Score')
# set consistent y limit to see the difference across 3 plots
ax3.set_ylim([16, 30])

# Fill with colors
colors = ['#C5F9D7', '#F7D486', '#F27A7D']
for box in (act_ts_plot, act_lo_ts_plot, act_hi_ts_plot):
    for patch, color in zip(box['boxes'], colors):
        patch.set_facecolor(color)
    for median in box['medians']:
        median.set(color ='blue', linewidth = 3)

# Include horizontal grid lines for greater ease in reading the values (OPTIONAL)
# ax1.grid(axis='y')
# ax2.grid(axis='y')
# ax3.grid(axis='y')

# %% [markdown]
# **Interpretation**:
# - The 3 plots above show the spread of the (i) overall state average total score; (ii) state average total score for states with < 10% ACT participation rate; and (iii) state average total score for states with > 90% ACT participation rate, yearly.
#  - For (i), there are no clear outliers and the range is fairly stable.
#  - For (ii), since there is only 1 U.S. state of Maine with < 10% ACT participation rate, the boxplots across all 3 years collapse to 3 horizontal blue lines coinciding with the median for each year. Maine's state average score is fairly stable across all 3 years.
#  - For (iii), this group of students have lower state average score than (i), as seen by the lower boxplots. The scores are more consistent, as seen by the smaller IQR. This also indicates an inverse relationship between ACT participation rate and score. As these states have a high ACT participation rate, we are more confident to conclude the state's overall performance as the data is generally more representative of the population. Outliers are seen on the upper end of the boxplots for 2019.

# %%
# Filter SAT dataset for states with > 90% SAT participation rate yearly
sat_hi_participation_rate = m_sat_merged.loc[(m_sat_merged['sat_participation_rate_2017'] > 0.9) & 
                                             (m_sat_merged['sat_participation_rate_2018'] > 0.9) &
                                             (m_sat_merged['sat_participation_rate_2019'] > 0.9)]

# Check the size of the dataframe
sat_hi_participation_rate.shape
# Out:
# (7, 9)

# %%
# Filter SAT dataset for states with < 10% SAT participation rate yearly
sat_lo_participation_rate = m_sat_merged.loc[(m_sat_merged['sat_participation_rate_2017'] < 0.1) & 
                                             (m_sat_merged['sat_participation_rate_2018'] < 0.1) &
                                             (m_sat_merged['sat_participation_rate_2019'] < 0.1)]

# Check the size of the dataframe
sat_lo_participation_rate.shape
# Out:
# (16, 9)

# %%
# Boxplot to show the relationship between average total score for all states 
# vs state with < 10% SAT participation rate vs state with > 90% SAT participation rate

# Create a dictionary where keys are the years, and values are the average total scores per state
sat_ts = {'sat_2017': m_sat_merged['sat_total_score_2017'], 
          'sat_2018': m_sat_merged['sat_total_score_2018'], 
          'sat_2019': m_sat_merged['sat_total_score_2019']}

# Create a dictionary where keys are the years, and 
# values are the average total scores per state for state < 10% SAT participation rate
sat_lo_ts = {'sat_2017': sat_lo_participation_rate['sat_total_score_2017'], 
             'sat_2018': sat_lo_participation_rate['sat_total_score_2018'], 
             'sat_2019': sat_lo_participation_rate['sat_total_score_2019']}

# Create a dictionary where keys are the years, and 
# values are the average total scores per state for state > 90% SAT participation rate
sat_hi_ts = {'sat_2017': sat_hi_participation_rate['sat_total_score_2017'], 
             'sat_2018': sat_hi_participation_rate['sat_total_score_2018'], 
             'sat_2019': sat_hi_participation_rate['sat_total_score_2019']}

# Plot them as 3 subplots
plt.rcParams['font.size'] = 20
fig, (ax1, ax2, ax3) = plt.subplots(nrows = 3, ncols = 1, figsize = (15, 24))
sat_ts_plot = ax1.boxplot(sat_ts.values(),
                         patch_artist = True,
                         labels = ['2017', '2018', '2019'])  
ax1.set_title('State Average Total Score for SAT by Years',
             {'fontsize': 20, 'fontweight': 'bold'})
ax1.set_xlabel('Year')
ax1.set_ylabel('Total SAT Score')
# set consistent y limit to see the difference across 3 plots
ax1.set_ylim([900, 1400])

sat_lo_ts_plot = ax2.boxplot(sat_lo_ts.values(), 
                             patch_artist = True,
                             labels = ['2017', '2018', '2019']) 
ax2.set_title('State (< 10% Participation Rate) Average Total Score for SAT by Years',
             {'fontsize': 20, 'fontweight': 'bold'})
ax2.set_xlabel('Year')
ax2.set_ylabel('Total SAT Score')
# set consistent y limit to see the difference across 3 plots
ax2.set_ylim([900, 1400])

sat_hi_ts_plot = ax3.boxplot(sat_hi_ts.values(), 
                             patch_artist = True,
                             labels = ['2017', '2018', '2019']) 
ax3.set_title('State (> 90% Participation Rate) Average Total Score for SAT by Years',
             {'fontsize': 20, 'fontweight': 'bold'})
ax3.set_xlabel('Year')
ax3.set_ylabel('Total SAT Score')
# set consistent y limit to see the difference across 3 plots
ax3.set_ylim([900, 1400])

# Fill with colors
colors = ['#C5F9D7', '#F7D486', '#F27A7D']
for box in (sat_ts_plot, sat_lo_ts_plot, sat_hi_ts_plot):
    for patch, color in zip(box['boxes'], colors):
        patch.set_facecolor(color)
    for median in box['medians']:
        median.set(color ='blue', linewidth = 3)

# Include horizontal grid lines for greater ease in reading the values (OPTIONAL)
# ax1.grid(axis='y')
# ax2.grid(axis='y')
# ax3.grid(axis='y')

# %% [markdown]
# **Interpretation**:
# - The 3 plots above show the spread of the (i) overall state average total score; (ii) state average total score for states with < 10% SAT participation rate; and (iii) state average total score for states with > 90% SAT participation rate, yearly.
#  - For (i), there are no clear outliers and the range is fairly stable.
#  - For (ii), this group of students have higher state average score than (i), as seen by the higher boxplots. The scores are also more consistent, as seen by the smaller interquartile range (IQR). This indicates an inverse relationship between SAT participation rate and score. While they have a higher state average scores, we cannot conclude that these states' overall performance is better, as the data could be biased with the low SAT participation rate. Outliers are also seen on the lower end of the boxplots across all 3 years.
#  - For (iii), this group of students have lower state average score than (i), as seen by the lower boxplots. Similar to (ii), the scores are also more consistent, as seen by the smaller IQR. This also indicates an inverse relationship between SAT participation rate and score. As these states have a high SAT participation rate, we are more confident to conclude the state's overall performance as the data is generally more representative of the population. Outliers are also seen on the lower end of the boxplot for 2017.

# %%
# Plot 3 scatterplots side by side to view relationship between ACT participation rate and scores from 2017 to 2019
act_fig, act_axes = plt.subplots(1, 3, figsize=(15, 6), sharey=True)
act_fig.suptitle('Inverse Relationship between State Average Total Score and ACT Participation Rates from 2017 to 2019', fontsize = 18, fontweight = 'bold')

act_scatter_2017 = sns.scatterplot(data = m_act_merged, x = 'act_participation_rate_2017', y = 'act_total_score_2017', color = '#20A39E', ax = act_axes[0])
act_scatter_2018 = sns.scatterplot(data = m_act_merged, x = 'act_participation_rate_2018', y = 'act_total_score_2018', color = '#FFBA49', ax = act_axes[1])
act_scatter_2019 = sns.scatterplot(data = m_act_merged, x = 'act_participation_rate_2019', y = 'act_total_score_2019', color = '#EF5B5B', ax = act_axes[2])

# Setting the labels
act_scatter_2017.set_xlabel('ACT Participation Rate')
act_scatter_2017.set_ylabel('State Average Total Score')
act_scatter_2018.set_xlabel('ACT Participation Rate')
act_scatter_2018.set_ylabel('State Average Total Score')
act_scatter_2019.set_xlabel('ACT Participation Rate')
act_scatter_2019.set_ylabel('State Average Total Score')
# Out:
# Text(0, 0.5, 'State Average Total Score')

# %% [markdown]
# **Interpretation**:
# - The 3 scatter plots above show the relationship beween the ACT participation rate and the state average total score for years 2017 to 2019. As ACT participation rate increases, the average total score generally decreases, indicating an inverse relationship. This observation is generally consistent when we compare these plots from 2017 (left) to 2018 (middle) to 2019 (right), though there may be some outliers.

# %%
# Plot 3 scatterplots side by side to view relationship between SAT participation rate and scores from 2017 to 2019
sat_fig, sat_axes = plt.subplots(1, 3, figsize=(15, 6), sharey=True)
sat_fig.suptitle('Inverse Relationship between State Average Total Score and SAT Participation Rates from 2017 to 2019', fontsize = 18, fontweight = 'bold')

sat_scatter_2017 = sns.scatterplot(data = m_sat_merged, x = 'sat_participation_rate_2017', y = 'sat_total_score_2017', color = '#20A39E', ax = sat_axes[0])
sat_scatter_2018 = sns.scatterplot(data = m_sat_merged, x = 'sat_participation_rate_2018', y = 'sat_total_score_2018', color = '#FFBA49', ax = sat_axes[1])
sat_scatter_2019 = sns.scatterplot(data = m_sat_merged, x = 'sat_participation_rate_2019', y = 'sat_total_score_2019', color = '#EF5B5B', ax = sat_axes[2])

# Setting the labels
sat_scatter_2017.set_xlabel('SAT Participation Rate')
sat_scatter_2017.set_ylabel('State Average Total Score')
sat_scatter_2018.set_xlabel('SAT Participation Rate')
sat_scatter_2018.set_ylabel('State Average Total Score')
sat_scatter_2019.set_xlabel('SAT Participation Rate')
sat_scatter_2019.set_ylabel('State Average Total Score')
# Out:
# Text(0, 0.5, 'State Average Total Score')

# %% [markdown]
# **Interpretation**:
# - Similarly, the 3 scatter plots above show the relationship beween the SAT participation rate and the state average total score for years 2017 to 2019. As SAT participation rate increases, the average total score generally decreases, indicating an inverse relationship. This observation is generally consistent when we compare these plots from 2017 (left) to 2018 (middle) to 2019 (right), though there may be some outliers.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **Conclusions**:
# - The successful combinations of strategies / tactics were gleaned from the various analyses done on both ACT and SAT above, complemented by additional secondary research, and include:
#  - Negotiate preferably long term contracts, with optional renewal extensions at same/better terms;
#  - (The College Board's) state lobbying efforts and interventions with passing of relevant legislations;
#  - Convincing relevant officials to make ACT/SAT compulsory and subsidise test when appropriate;
#  - “ACT/SAT school day” programs to allow students to take test for free during the week in school;
#  - Increased test frequencies;
#  - etc.
# <BR>
#
#
# - There is generally an inverse relationship between both ACT and SAT scores and their corresponding participation rates. Lower ACT/SAT participation rate typically have higher state average score, and vice versa. This is likely due to biased data in states with low participation rate, as the students who took the test are probably better prepared hence applied for the ACT/SAT voluntarily.
# <BR>
#
#
#
# **Recommendations**:<BR>
# Having analysed the trends in both the ACT and SAT participation rates above, I have identified the following strategies to improve 2020 ACT participation rates and eventually reclaim ACT's position as the nation’s most widely used college admission test:
# <BR>
#
# - Firstly, I would generally recommend targeting the following stakeholders in decreasing priority:
#  - States with no contracts and low participation rates;
#  - States with no contracts;
#  - States with expiring contract;
#  - States with contracts pending renewal and/or extension;
#  - State Department of Education;
#  - High school administrators;
#  - Parents;
#  - High School 11th graders;
#  - etc.
# <BR>
#
#
# - Secondly, when negotiating with stakeholders such as State Department of Education and high school administrators, the the preferred terms in decreasing priority are as following:
#  - Long term contracts, with optional renewal extensions at same/better terms;
#  - Long term contracts;
#  - Shorter term contracts, with optional renewal extensions at same/better terms;
#  - Shorter term contracts;
#  - etc.
# <BR>
#
#
# - Thirdly, while negotiating with these stakeholders, we shall highlight the relevant additional / optional benefits from the following:
#  - ACT's good predictive ability of undergraduate educational performance and success is backed by independent research [(source)](https://www.researchgate.net/profile/Joel-Wao/publication/316554186_SAT_and_ACT_Scores_as_Predictors_of_Undergraduate_GPA_Scores_of_Construction_Science_and_Management_Students/links/590399ab0f7e9bc0d58d7e30/SAT-and-ACT-Scores-as-Predictors-of-Undergraduate-GPA-Scores-of-Construction-Science-and-Management-Students.pdf)
#  - Compulsory and Free / Subsidised rates
#  - “ACT school day” during the week in school
#  - ACT Section Retesting
#  - ACT Online testing
#  - ACT “superscoring”
#  - etc.
# <BR>
#
#
# - Lastly, the above strategies / tactics should be complemented by ACT's advertising, branding and marketing efforts as follows:
#  - Leadership Interviews
#  - Roadshows / Tradeshows
#  - Seminars / Webinars / YouTube Videos
#  - Blog / Guest Posts
#  - Press Releases
#  - Digital Marketing
#  - Banners / Posters
#  - TV / Radio / Cable Advertisements
#  - etc.
# <BR>
#
#
# When the above strategies are skillfully executed, I am confident that we stand to potentially improve 2020 ACT participation rates and eventually reclaim ACT's position as the nation’s most widely used college admission test!

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
